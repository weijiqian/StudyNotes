# %% [markdown]
# + 数据源 [腾讯疫情实时追踪](https://news.qq.com/zt2020/page/feiyan.htm?from=timeline&isappinstalled=0)

# %% [markdown]
# ### 第一部分 网页分析

# %% [markdown]
# 今天重新整理了一下，发现数据结构和之前的有所变化，把具体的操作步骤也说一下吧！
# 打开网址推荐使用火狐浏览器，F12 进入开发者工具（刷新一下页面），如下：
#
# ![image.png](attachment:image.png)
#
# 分析请求头
# - name=disease_h5 是数据位置
# - callback=jQuery341021795676971428168_1580642523637_=1580642523638返回当前时间戳的一个函数
# 所以我们请求的URL为：https://view.inews.qq.com/g2/getOnsInfo?name=disease_h5
# （自己尝试一下，这里需要找规律）
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 第二部分 数据准备

# %% [markdown]
# #### 导入模块

# %%
import time 
import json
import requests
from datetime import datetime
import pandas as pd 
import numpy as np

# %% [markdown]
# #### 抓取数据

# %%
def catch_data():
    url = 'https://view.inews.qq.com/g2/getOnsInfo?name=disease_h5'
    reponse = requests.get(url=url).json()
    #返回数据字典
    data = json.loads(reponse['data'])
    return data

# %%
data = catch_data()
data.keys()
# Out:
# dict_keys(['chinaTotal', 'chinaAdd', 'lastUpdateTime', 'areaTree', 'chinaDayList', 'chinaDayAddList'])

# %% [markdown]
# #### 数据处理

# %%
# 数据集包括["国内总量","国内新增","更新时间","数据明细","每日数据","每日新增"]

lastUpdateTime = data['lastUpdateTime']
chinaTotal = data['chinaTotal']
chinaAdd = data['chinaAdd']
print(chinaTotal)
print(chinaAdd)
# Out:
# {'confirm': 17238, 'suspect': 21558, 'dead': 361, 'heal': 475}
# {'confirm': 2858, 'suspect': 2014, 'dead': 57, 'heal': 147}

# %% [markdown]
# ##### 国内数据处理 第一步

# %%
# 数据明细，数据结构比较复杂，一步一步打印出来看，先明白数据结构
areaTree = data['areaTree']
# 国内数据
china_data = areaTree[0]['children']
china_list = []
for a in range(len(china_data)):
    province = china_data[a]['name']
    province_list = china_data[a]['children']
    for b in range(len(province_list)):
        city = province_list[b]['name']
        total = province_list[b]['total']
        today = province_list[b]['today']
        china_dict = {}
        china_dict['province'] = province
        china_dict['city'] = city
        china_dict['total'] = total
        china_dict['today'] = today
        china_list.append(china_dict)
        
china_data = pd.DataFrame(china_list)
china_data.head()
# Out:
#   city province                                              today  \
# 0   武汉       湖北  {'confirm': 1033, 'suspect': 0, 'dead': 41, 'h...
# 1   黄冈       湖北  {'confirm': 244, 'suspect': 0, 'dead': 2, 'hea...
# 2   孝感       湖北  {'confirm': 169, 'suspect': 0, 'dead': 0, 'hea...
# 3   襄阳       湖北  {'confirm': 107, 'suspect': 0, 'dead': 0, 'hea...
# 4   荆州       湖北  {'confirm': 166, 'suspect': 0, 'dead': 2, 'hea...
#
#                                                total
# 0  {'confirm': 5142, 'suspect': 0, 'dead': 265, '...
# 1  {'confirm': 1246, 'suspect': 0, 'dead': 17, 'h...
# 2  {'confirm': 918, 'suspect': 0, 'dead': 14, 'he...
# 3  {'confirm': 548, 'suspect': 0, 'dead': 0, 'hea...
# 4  {'confirm': 499, 'suspect': 0, 'dead': 6, 'hea...

# %% [markdown]
# ##### 国内数据处理 第二步

# %%
# 定义数据处理函数
def confirm(x):
    confirm = eval(str(x))['confirm']
    return confirm
def suspect(x):
    suspect = eval(str(x))['suspect']
    return suspect
def dead(x):
    dead = eval(str(x))['dead']
    return dead
def heal(x):
    heal =  eval(str(x))['heal']
    return heal
# 函数映射
china_data['confirm'] = china_data['total'].map(confirm)
china_data['suspect'] = china_data['total'].map(suspect)
china_data['dead'] = china_data['total'].map(dead)
china_data['heal'] = china_data['total'].map(heal)
china_data['addconfirm'] = china_data['today'].map(confirm)
china_data['addsuspect'] = china_data['today'].map(suspect)
china_data['adddead'] = china_data['today'].map(dead)
china_data['addheal'] = china_data['today'].map(heal)
china_data = china_data[["province","city","confirm","suspect","dead","heal","addconfirm","addsuspect","adddead","addheal"]]
china_data.head()
# Out:
#   province city  confirm  suspect  dead  heal  addconfirm  addsuspect  \
# 0       湖北   武汉     5142        0   265   181        1033           0
# 1       湖北   黄冈     1246        0    17    27         244           0
# 2       湖北   孝感      918        0    14     2         169           0
# 3       湖北   襄阳      548        0     0     0         107           0
# 4       湖北   荆州      499        0     6     1         166           0
#
#    adddead  addheal
# 0       41        0
# 1        2        0
# 2        0        0
# 3        0        0
# 4        2        0

# %% [markdown]
# ##### 国际数据处理

# %%
global_data = pd.DataFrame(data['areaTree'])
global_data['confirm'] = global_data['total'].map(confirm)
global_data['suspect'] = global_data['total'].map(suspect)
global_data['dead'] = global_data['total'].map(dead)
global_data['heal'] = global_data['total'].map(heal)
global_data['addconfirm'] = global_data['today'].map(confirm)
global_data['addsuspect'] = global_data['today'].map(suspect)
global_data['adddead'] = global_data['today'].map(dead)
global_data['addheal'] = global_data['today'].map(heal)
world_name = pd.read_excel("世界各国中英文对照.xlsx")
global_data = pd.merge(global_data,world_name,left_on ="name",right_on = "中文",how="inner")
global_data = global_data[["name","英文","confirm","suspect","dead","heal","addconfirm","addsuspect","adddead","addheal"]]
global_data.head()
# Out:
#   name                  英文  confirm  suspect  dead  heal  addconfirm  \
# 0   中国               China    17219        0   361   480        2732
# 1   日本               Japan       20        0     0     1           0
# 2   泰国            Thailand       19        0     0     7           0
# 3  新加坡           Singapore       18        0     0     0           0
# 4   韩国  Korea(republic of)       15        0     0     0           0
#
#    addsuspect  adddead  addheal
# 0           0       57       53
# 1           0        0        0
# 2           0        0        0
# 3           0        0        0
# 4           0        0        0

# %% [markdown]
# ##### 日数据处理

# %%
chinaDayList = pd.DataFrame(data['chinaDayList'])
chinaDayList = chinaDayList[['date','confirm','suspect','dead','heal']]
chinaDayList.head()
# Out:
#     date confirm suspect dead heal
# 0  01.13      41       0    1    0
# 1  01.14      41       0    1    0
# 2  01.15      41       0    2    5
# 3  01.16      45       0    2    8
# 4  01.17      62       0    2   12

# %% [markdown]
# ##### 日新增数据处理

# %%
chinaDayAddList = pd.DataFrame(data['chinaDayAddList'])
chinaDayAddList = chinaDayAddList[['date','confirm','suspect','dead','heal']]
chinaDayAddList.head()
# Out:
#     date confirm suspect dead heal
# 0  01.20      77      27    0    0
# 1  01.21     149      53    3    0
# 2  01.22     131     257    8    0
# 3  01.23     259     680    8    6
# 4  01.24     444    1118   16    3

# %% [markdown]
# ### 数据可视化

# %% [markdown]
# #### 总数据明细

# %%
from pyecharts.charts import * #导入所有图表
from pyecharts import options as opts
#导入pyecharts的主题（如果不使用可以跳过）
from pyecharts.globals import ThemeType

# %%
total_pie = Pie(init_opts=opts.InitOpts(theme=ThemeType.WESTEROS,width = '500px',height ='350px'))  #设置主题，和画布大小
total_pie.add("",[list(z) for z in zip(chinaTotal.keys(), chinaTotal.values())],
            center=["50%", "50%"], #图的位置
            radius=[50, 80])   #内外径大小
total_pie.set_global_opts(
            title_opts=opts.TitleOpts(title="全国总量",subtitle=("截止"+lastUpdateTime)))
total_pie.set_series_opts(label_opts=opts.LabelOpts(formatter="{c}"))  #标签格式
total_pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'westeros':'https://assets.pyecharts.org/assets/themes/westeros'
#         }
#     });
# </script>
#
#         <div id="df41be401be54cb6bd113d776a0d5a49" style="width:500px; height:350px;"></div>
#
# <script>
#         require(['echarts', 'westeros'], function(echarts) {
#                 var chart_df41be401be54cb6bd113d776a0d5a49 = echarts.init(
#                     document.getElementById('df41be401be54cb6bd113d776a0d5a49'), 'westeros', {renderer: 'canvas'});
#                 var option_df41be401be54cb6bd113d776a0d5a49 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "confirm",
#                     "value": 17238
#                 },
#                 {
#                     "name": "suspect",
#                     "value": 21558
#                 },
#                 {
#                     "name": "dead",
#                     "value": 361
#                 },
#                 {
#                     "name": "heal",
#                     "value": 475
#                 }
#             ],
#             "radius": [
#                 50,
#                 80
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "confirm",
#                 "suspect",
#                 "dead",
#                 "heal"
#             ],
#             "selected": {},
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5168\u56fd\u603b\u91cf",
#             "subtext": "\u622a\u6b622020-02-03 11:20:18"
#         }
#     ]
# };
#                 chart_df41be401be54cb6bd113d776a0d5a49.setOption(option_df41be401be54cb6bd113d776a0d5a49);
#         });
#     </script>

# %%
totaladd_pie = Pie(init_opts=opts.InitOpts(theme=ThemeType.WESTEROS,width = '500px',height ='350px'))  #设置主题，和画布大小
totaladd_pie.add("",[list(z) for z in zip(chinaAdd.keys(), chinaAdd.values())],
            center=["50%", "50%"],
            radius=[50, 80])
totaladd_pie.set_global_opts(
            title_opts=opts.TitleOpts(title="昨日新增"))
totaladd_pie.set_series_opts(label_opts=opts.LabelOpts(formatter="{c}"))  #标签格式
totaladd_pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'westeros':'https://assets.pyecharts.org/assets/themes/westeros'
#         }
#     });
# </script>
#
#         <div id="e7f89ced2eee4f72aabf78c05ab56dc1" style="width:500px; height:350px;"></div>
#
# <script>
#         require(['echarts', 'westeros'], function(echarts) {
#                 var chart_e7f89ced2eee4f72aabf78c05ab56dc1 = echarts.init(
#                     document.getElementById('e7f89ced2eee4f72aabf78c05ab56dc1'), 'westeros', {renderer: 'canvas'});
#                 var option_e7f89ced2eee4f72aabf78c05ab56dc1 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "confirm",
#                     "value": 2858
#                 },
#                 {
#                     "name": "suspect",
#                     "value": 2014
#                 },
#                 {
#                     "name": "dead",
#                     "value": 57
#                 },
#                 {
#                     "name": "heal",
#                     "value": 147
#                 }
#             ],
#             "radius": [
#                 50,
#                 80
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "confirm",
#                 "suspect",
#                 "dead",
#                 "heal"
#             ],
#             "selected": {},
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u6628\u65e5\u65b0\u589e"
#         }
#     ]
# };
#                 chart_e7f89ced2eee4f72aabf78c05ab56dc1.setOption(option_e7f89ced2eee4f72aabf78c05ab56dc1);
#         });
#     </script>

# %% [markdown]
# #### 全球疫情热图

# %%
world_map = Map(init_opts=opts.InitOpts(theme=ThemeType.WESTEROS))
world_map.add("",[list(z) for z in zip(list(global_data["英文"]), list(global_data["confirm"]))], "world",is_map_symbol_show=False)
world_map.set_global_opts(title_opts=opts.TitleOpts(title="2019_nCoV-世界疫情地图"),
                          visualmap_opts=opts.VisualMapOpts(is_piecewise=True,
                          pieces = [
                        {"min": 101 , "label": '>100'}, #不指定 max，表示 max 为无限大
                        {"min": 10, "max": 100, "label": '10-100'},
                        {"min": 0, "max": 9, "label": '0-9' }]))
world_map.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
world_map.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world', 'westeros':'https://assets.pyecharts.org/assets/themes/westeros'
#         }
#     });
# </script>
#
#         <div id="c938cdb9be164ce89a16c8c3788edf61" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'world', 'westeros'], function(echarts) {
#                 var chart_c938cdb9be164ce89a16c8c3788edf61 = echarts.init(
#                     document.getElementById('c938cdb9be164ce89a16c8c3788edf61'), 'westeros', {renderer: 'canvas'});
#                 var option_c938cdb9be164ce89a16c8c3788edf61 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "map",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "world",
#             "data": [
#                 {
#                     "name": "China",
#                     "value": 17219
#                 },
#                 {
#                     "name": "Japan",
#                     "value": 20
#                 },
#                 {
#                     "name": "Thailand",
#                     "value": 19
#                 },
#                 {
#                     "name": "Singapore",
#                     "value": 18
#                 },
#                 {
#                     "name": "Korea(republic of)",
#                     "value": 15
#                 },
#                 {
#                     "name": "Australia",
#                     "value": 12
#                 },
#                 {
#                     "name": "U.S.A",
#                     "value": 11
#                 },
#                 {
#                     "name": "Germany",
#                     "value": 10
#                 },
#                 {
#                     "name": "Malaysia",
#                     "value": 8
#                 },
#                 {
#                     "name": "Vietnam",
#                     "value": 7
#                 },
#                 {
#                     "name": "France",
#                     "value": 6
#                 },
#                 {
#                     "name": "Canada",
#                     "value": 4
#                 },
#                 {
#                     "name": "Philippines",
#                     "value": 2
#                 },
#                 {
#                     "name": "India",
#                     "value": 2
#                 },
#                 {
#                     "name": "Italy",
#                     "value": 2
#                 },
#                 {
#                     "name": "United Kingdom",
#                     "value": 2
#                 },
#                 {
#                     "name": "Russia",
#                     "value": 2
#                 },
#                 {
#                     "name": "Nepal",
#                     "value": 1
#                 },
#                 {
#                     "name": "Sri Lanka",
#                     "value": 1
#                 },
#                 {
#                     "name": "Finland",
#                     "value": 1
#                 },
#                 {
#                     "name": "Sweden",
#                     "value": 1
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": false,
#             "emphasis": {},
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "2019_nCoV-\u4e16\u754c\u75ab\u60c5\u5730\u56fe"
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "pieces": [
#             {
#                 "min": 101,
#                 "label": ">100"
#             },
#             {
#                 "min": 10,
#                 "max": 100,
#                 "label": "10-100"
#             },
#             {
#                 "min": 0,
#                 "max": 9,
#                 "label": "0-9"
#             }
#         ]
#     }
# };
#                 chart_c938cdb9be164ce89a16c8c3788edf61.setOption(option_c938cdb9be164ce89a16c8c3788edf61);
#         });
#     </script>

# %% [markdown]
# #### 中国疫情地图热图绘制

# %%
#数据处理
area_data = china_data.groupby("province")["confirm"].sum().reset_index()
area_data.columns = ["province","confirm"]

# %%
area_map = Map(init_opts=opts.InitOpts(theme=ThemeType.WESTEROS))
area_map.add("",[list(z) for z in zip(list(area_data["province"]), list(area_data["confirm"]))], "china",is_map_symbol_show=False)
area_map.set_global_opts(title_opts=opts.TitleOpts(title="2019_nCoV中国疫情地图"),visualmap_opts=opts.VisualMapOpts(is_piecewise=True,
                pieces = [
                        {"min": 1001 , "label": '>1000',"color": "#893448"}, #不指定 max，表示 max 为无限大
                        {"min": 500, "max": 1000, "label": '500-1000',"color": "#ff585e"},
                        {"min": 101, "max": 499, "label": '101-499',"color": "#fb8146"},
                        {"min": 10, "max": 100, "label": '10-100',"color": "#ffb248"},
                        {"min": 0, "max": 9, "label": '0-9',"color" : "#fff2d1" }]))
area_map.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china', 'westeros':'https://assets.pyecharts.org/assets/themes/westeros'
#         }
#     });
# </script>
#
#         <div id="4afca4394dc74d64aa320c7831ca4bd1" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china', 'westeros'], function(echarts) {
#                 var chart_4afca4394dc74d64aa320c7831ca4bd1 = echarts.init(
#                     document.getElementById('4afca4394dc74d64aa320c7831ca4bd1'), 'westeros', {renderer: 'canvas'});
#                 var option_4afca4394dc74d64aa320c7831ca4bd1 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "map",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 193
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 105
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 27
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 191
#                 },
#                 {
#                     "name": "\u53f0\u6e7e",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 23
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 231
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 48
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 28
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 340
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 230
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 66
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 632
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 127
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 21
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 236
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 333
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 113
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 566
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 661
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 64
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 11177
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 463
#                 },
#                 {
#                     "name": "\u6fb3\u95e8",
#                     "value": 8
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 51
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 159
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 38
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 70
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 300
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 116
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 11
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 15
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 95
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": false,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "2019_nCoV\u4e2d\u56fd\u75ab\u60c5\u5730\u56fe"
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "pieces": [
#             {
#                 "min": 1001,
#                 "label": ">1000",
#                 "color": "#893448"
#             },
#             {
#                 "min": 500,
#                 "max": 1000,
#                 "label": "500-1000",
#                 "color": "#ff585e"
#             },
#             {
#                 "min": 101,
#                 "max": 499,
#                 "label": "101-499",
#                 "color": "#fb8146"
#             },
#             {
#                 "min": 10,
#                 "max": 100,
#                 "label": "10-100",
#                 "color": "#ffb248"
#             },
#             {
#                 "min": 0,
#                 "max": 9,
#                 "label": "0-9",
#                 "color": "#fff2d1"
#             }
#         ]
#     }
# };
#                 chart_4afca4394dc74d64aa320c7831ca4bd1.setOption(option_4afca4394dc74d64aa320c7831ca4bd1);
#         });
#     </script>

# %% [markdown]
# #### 绘制每日数据趋势

# %% [markdown]
# ##### 每日累计数据趋势

# %%
line1 = Line(init_opts=opts.InitOpts(theme=ThemeType.WESTEROS))
line1.add_xaxis(list(chinaDayList["date"]))
line1.add_yaxis("治愈",list(chinaDayList["heal"]),is_smooth=True)
line1.add_yaxis("死亡", list(chinaDayList["dead"]),is_smooth=True)
line1.set_global_opts(title_opts=opts.TitleOpts(title="Line1-治愈与死亡趋势"))
line1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'westeros':'https://assets.pyecharts.org/assets/themes/westeros'
#         }
#     });
# </script>
#
#         <div id="8723f81496e14ff1aa3e7ff4b84eaa94" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'westeros'], function(echarts) {
#                 var chart_8723f81496e14ff1aa3e7ff4b84eaa94 = echarts.init(
#                     document.getElementById('8723f81496e14ff1aa3e7ff4b84eaa94'), 'westeros', {renderer: 'canvas'});
#                 var option_8723f81496e14ff1aa3e7ff4b84eaa94 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "line",
#             "name": "\u6cbb\u6108",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": true,
#             "step": false,
#             "data": [
#                 [
#                     "01.13",
#                     "0"
#                 ],
#                 [
#                     "01.14",
#                     "0"
#                 ],
#                 [
#                     "01.15",
#                     "5"
#                 ],
#                 [
#                     "01.16",
#                     "8"
#                 ],
#                 [
#                     "01.17",
#                     "12"
#                 ],
#                 [
#                     "01.18",
#                     "17"
#                 ],
#                 [
#                     "01.19",
#                     "18"
#                 ],
#                 [
#                     "01.20",
#                     "25"
#                 ],
#                 [
#                     "01.21",
#                     "25"
#                 ],
#                 [
#                     "01.22",
#                     "25"
#                 ],
#                 [
#                     "01.23",
#                     "34"
#                 ],
#                 [
#                     "01.24",
#                     "38"
#                 ],
#                 [
#                     "01.25",
#                     "49"
#                 ],
#                 [
#                     "01.26",
#                     "51"
#                 ],
#                 [
#                     "01.27",
#                     "60"
#                 ],
#                 [
#                     "01.28",
#                     "103"
#                 ],
#                 [
#                     "01.29",
#                     "124"
#                 ],
#                 [
#                     "01.30",
#                     "171"
#                 ],
#                 [
#                     "01.31",
#                     "243"
#                 ],
#                 [
#                     "02.01",
#                     "328"
#                 ],
#                 [
#                     "02.02",
#                     "475"
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u6b7b\u4ea1",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": true,
#             "step": false,
#             "data": [
#                 [
#                     "01.13",
#                     "1"
#                 ],
#                 [
#                     "01.14",
#                     "1"
#                 ],
#                 [
#                     "01.15",
#                     "2"
#                 ],
#                 [
#                     "01.16",
#                     "2"
#                 ],
#                 [
#                     "01.17",
#                     "2"
#                 ],
#                 [
#                     "01.18",
#                     "3"
#                 ],
#                 [
#                     "01.19",
#                     "4"
#                 ],
#                 [
#                     "01.20",
#                     "6"
#                 ],
#                 [
#                     "01.21",
#                     "9"
#                 ],
#                 [
#                     "01.22",
#                     "17"
#                 ],
#                 [
#                     "01.23",
#                     "25"
#                 ],
#                 [
#                     "01.24",
#                     "41"
#                 ],
#                 [
#                     "01.25",
#                     "56"
#                 ],
#                 [
#                     "01.26",
#                     "80"
#                 ],
#                 [
#                     "01.27",
#                     "106"
#                 ],
#                 [
#                     "01.28",
#                     "132"
#                 ],
#                 [
#                     "01.29",
#                     "170"
#                 ],
#                 [
#                     "01.30",
#                     "213"
#                 ],
#                 [
#                     "01.31",
#                     "259"
#                 ],
#                 [
#                     "02.01",
#                     "304"
#                 ],
#                 [
#                     "02.02",
#                     "361"
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6cbb\u6108",
#                 "\u6b7b\u4ea1"
#             ],
#             "selected": {
#                 "\u6cbb\u6108": true,
#                 "\u6b7b\u4ea1": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "01.13",
#                 "01.14",
#                 "01.15",
#                 "01.16",
#                 "01.17",
#                 "01.18",
#                 "01.19",
#                 "01.20",
#                 "01.21",
#                 "01.22",
#                 "01.23",
#                 "01.24",
#                 "01.25",
#                 "01.26",
#                 "01.27",
#                 "01.28",
#                 "01.29",
#                 "01.30",
#                 "01.31",
#                 "02.01",
#                 "02.02"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,

# %% [markdown]
# ##### 每日累计确诊趋势

# %%
line2 = Line(init_opts=opts.InitOpts(theme=ThemeType.SHINE))
line2.add_xaxis(list(chinaDayList["date"]))
line2.add_yaxis("确诊",list(chinaDayList["confirm"]))
line2.add_yaxis("疑似", list(chinaDayList["suspect"]))
line2.set_global_opts(title_opts=opts.TitleOpts(title="Line2-确诊与疑似趋势"))
line2.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'shine':'https://assets.pyecharts.org/assets/themes/shine'
#         }
#     });
# </script>
#
#         <div id="70d5c115f4344fffa84cf3aec7357c6a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'shine'], function(echarts) {
#                 var chart_70d5c115f4344fffa84cf3aec7357c6a = echarts.init(
#                     document.getElementById('70d5c115f4344fffa84cf3aec7357c6a'), 'shine', {renderer: 'canvas'});
#                 var option_70d5c115f4344fffa84cf3aec7357c6a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "line",
#             "name": "\u786e\u8bca",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "01.13",
#                     "41"
#                 ],
#                 [
#                     "01.14",
#                     "41"
#                 ],
#                 [
#                     "01.15",
#                     "41"
#                 ],
#                 [
#                     "01.16",
#                     "45"
#                 ],
#                 [
#                     "01.17",
#                     "62"
#                 ],
#                 [
#                     "01.18",
#                     "198"
#                 ],
#                 [
#                     "01.19",
#                     "275"
#                 ],
#                 [
#                     "01.20",
#                     "291"
#                 ],
#                 [
#                     "01.21",
#                     "440"
#                 ],
#                 [
#                     "01.22",
#                     "571"
#                 ],
#                 [
#                     "01.23",
#                     "830"
#                 ],
#                 [
#                     "01.24",
#                     "1287"
#                 ],
#                 [
#                     "01.25",
#                     "1975"
#                 ],
#                 [
#                     "01.26",
#                     "2744"
#                 ],
#                 [
#                     "01.27",
#                     "4515"
#                 ],
#                 [
#                     "01.28",
#                     "5974"
#                 ],
#                 [
#                     "01.29",
#                     "7711"
#                 ],
#                 [
#                     "01.30",
#                     "9692"
#                 ],
#                 [
#                     "01.31",
#                     "11791"
#                 ],
#                 [
#                     "02.01",
#                     "14380"
#                 ],
#                 [
#                     "02.02",
#                     "17205"
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u7591\u4f3c",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "01.13",
#                     "0"
#                 ],
#                 [
#                     "01.14",
#                     "0"
#                 ],
#                 [
#                     "01.15",
#                     "0"
#                 ],
#                 [
#                     "01.16",
#                     "0"
#                 ],
#                 [
#                     "01.17",
#                     "0"
#                 ],
#                 [
#                     "01.18",
#                     "0"
#                 ],
#                 [
#                     "01.19",
#                     "0"
#                 ],
#                 [
#                     "01.20",
#                     "54"
#                 ],
#                 [
#                     "01.21",
#                     "37"
#                 ],
#                 [
#                     "01.22",
#                     "393"
#                 ],
#                 [
#                     "01.23",
#                     "1072"
#                 ],
#                 [
#                     "01.24",
#                     "1965"
#                 ],
#                 [
#                     "01.25",
#                     "2684"
#                 ],
#                 [
#                     "01.26",
#                     " 5794"
#                 ],
#                 [
#                     "01.27",
#                     "6973"
#                 ],
#                 [
#                     "01.28",
#                     "9239"
#                 ],
#                 [
#                     "01.29",
#                     "12167"
#                 ],
#                 [
#                     "01.30",
#                     "15238"
#                 ],
#                 [
#                     "01.31",
#                     "17988"
#                 ],
#                 [
#                     "02.01",
#                     "19544"
#                 ],
#                 [
#                     "02.02",
#                     "21558"
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u786e\u8bca",
#                 "\u7591\u4f3c"
#             ],
#             "selected": {
#                 "\u786e\u8bca": true,
#                 "\u7591\u4f3c": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "01.13",
#                 "01.14",
#                 "01.15",
#                 "01.16",
#                 "01.17",
#                 "01.18",
#                 "01.19",
#                 "01.20",
#                 "01.21",
#                 "01.22",
#                 "01.23",
#                 "01.24",
#                 "01.25",
#                 "01.26",
#                 "01.27",
#                 "01.28",
#                 "01.29",
#                 "01.30",
#                 "01.31",
#                 "02.01",
#                 "02.02"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "of

# %% [markdown]
# ##### 每日新增

# %%
bar = Bar(init_opts=opts.InitOpts(theme=ThemeType.WESTEROS,width = '900px',height ='400px'))
bar .add_xaxis(list(chinaDayAddList["date"]))
bar .add_yaxis("确诊", list(chinaDayAddList["confirm"]))
bar .add_yaxis("疑似", list(chinaDayAddList["suspect"]))
bar .add_yaxis("死亡", list(chinaDayAddList["dead"]))
bar .add_yaxis("治愈", list(chinaDayAddList["heal"]))
bar .set_global_opts(title_opts=opts.TitleOpts(title="每日新增数据趋势"))
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'westeros':'https://assets.pyecharts.org/assets/themes/westeros'
#         }
#     });
# </script>
#
#         <div id="f361d22988f248c3a8dccd9da4c05962" style="width:900px; height:400px;"></div>
#
# <script>
#         require(['echarts', 'westeros'], function(echarts) {
#                 var chart_f361d22988f248c3a8dccd9da4c05962 = echarts.init(
#                     document.getElementById('f361d22988f248c3a8dccd9da4c05962'), 'westeros', {renderer: 'canvas'});
#                 var option_f361d22988f248c3a8dccd9da4c05962 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u786e\u8bca",
#             "data": [
#                 "77",
#                 "149",
#                 "131",
#                 "259",
#                 "444",
#                 "688",
#                 "769",
#                 "1771",
#                 "1459",
#                 "1737",
#                 "1982",
#                 "2102",
#                 "2590",
#                 "2829"
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u7591\u4f3c",
#             "data": [
#                 "27",
#                 "53",
#                 "257",
#                 "680",
#                 "1118",
#                 "1309",
#                 "3806",
#                 "2077",
#                 "3248",
#                 "4148",
#                 "4812",
#                 "5019",
#                 "4562",
#                 "5173"
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u6b7b\u4ea1",
#             "data": [
#                 "0",
#                 "3",
#                 "8",
#                 "8",
#                 "16",
#                 "15",
#                 "24",
#                 "26",
#                 "26",
#                 "38",
#                 "43",
#                 "46",
#                 "45",
#                 "57"
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u6cbb\u6108",
#             "data": [
#                 "0",
#                 "0",
#                 "0",
#                 "6",
#                 "3",
#                 "11",
#                 "2",
#                 "9",
#                 "43",
#                 "21",
#                 "47",
#                 "72",
#                 "85",
#                 "147"
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u786e\u8bca",
#                 "\u7591\u4f3c",
#                 "\u6b7b\u4ea1",
#                 "\u6cbb\u6108"
#             ],
#             "selected": {
#                 "\u786e\u8bca": true,
#                 "\u7591\u4f3c": true,
#                 "\u6b7b\u4ea1": true,
#                 "\u6cbb\u6108": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "01.20",
#                 "01.21",
#                 "01.22",
#                 "01.23",
#                 "01.24",
#                 "01.25",
#                 "01.26",
#                 "01.27",
#                 "01.28",
#                 "01.29",
#                 "01.30",
#                 "01.31",
#                 "02.01",
#                 "02.02"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u6bcf\u65e5\u65b0\u589e\u6570\u636e\u8d8b\u52bf"
#         }
#     ]
# };
#                 chart_f361d22988f248c3a8dccd9da4c05962.setOption(option_f361d22988f248c3a8dccd9da4c05962);
#         });
#     </script>

# %% [markdown]
# ### 图片汇总

# %%
page = Page()
page.add(total_pie)
page.add(totaladd_pie)
page.add(world_map)
page.add(area_map)
page.add(line1)
page.add(line2)
page.add(bar)
page.render("2019_nCoV 可视化.html")
# Out:
# 'C:\\Users\\junhu\\Desktop\\2019_nCoV\\2019_nCoV 可视化.html'
